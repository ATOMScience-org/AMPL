# %% [markdown]
# # Look at multitask-specific model metadata
# Multitask performance metrics can be pulled from `compare_models.get_multitask_perf_from_files_new()`

# %% [markdown]
# ## Import models and setup variables

# %%
from atomsci.ddm.pipeline import compare_models as cmp
# Out:
# Skipped loading some Jax models, missing a dependency. No module named 'jax'

# %% [markdown]
# The `result_dir` and `dataset_key` must be full, **absolute** paths.

# %%
result_dir='/home/apaulson/repos/AMPL_umbrella'

pred_type='classification'
MT_dataset_key='/home/apaulson/repos/AMPL_umbrella/ampl_berkeley/datasets/NEK9_binding_inhibition.csv'

# pred_type='regression'
# reg_dataset_key='/home/apaulson/repos/AMPL_umbrella/AMPL/atomsci/ddm/examples/tutorials2023/dataset/SLC6A2_3_4.csv'

# %% [markdown]
# ## Multitask model usage
#
# If you try to pull information from models trained on two different datasets you will throw an error. The error should help you narrow it down by providing your choices of dataset_keys.
#
# Occasionally people only have `tar.gz` model files and have lost (or never had) the corresponding folder structure from their filesystem. If this is the case, you can use the optional `tar=True` flag to have the function read tar files instead. This defaults to `False` for speed.

# %%
mtm=cmp.get_multitask_perf_from_files_new(result_dir, pred_type, tar=False)
# Out:
# Found data for 114 classification models under /home/apaulson/repos/AMPL_umbrella
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mtm=cmp.get_multitask_perf_from_files_new(result_dir, pred_type, tar=False)
#
# File ~/repos/AMPL_umbrella/AMPL/atomsci/ddm/pipeline/compare_models.py:1880, in get_multitask_perf_from_files_new(result_dir, pred_type, dataset_key, tar)
#    1878 # check for > 1 dataset
#    1879 if len(set(models.response_cols.astype(str)))>1:
# -> 1880     raise Exception (f"Warning: you cannot export multitask model performances for more than one dataset at a time. Please provide the dataset_key as an additional parameter. Your {pred_type} options are: {list(set(models.dataset_key))}.")
#    1882 num_model_tasks=models.num_model_tasks.iloc[0]
#    1884 # get task scores - long form and rename columns
#
# Exception: Warning: you cannot export multitask model performances for more than one dataset at a time. Please provide the dataset_key as an additional parameter. Your classification options are: ['/home/apaulson/repos/AMPL_umbrella/AMPL/atomsci/ddm/examples/tutorials2023/dataset/SLC6A3_classif_pKi_ge_8.csv', '/home/apaulson/repos/AMPL_umbrella/AMPL/atomsci/ddm/examples/tutorials2023/dataset/SLC6A2_3_4.csv', '/home/apaulson/repos/AMPL_umbrella/ampl_berkeley/datasets/NEK9_binding_inhibition.csv'].

# %% [markdown]
# Here we provide the dataset_key of interest and do not receive an error:

# %%
mtm=cmp.get_multitask_perf_from_files_new(result_dir, pred_type, dataset_key=MT_dataset_key)
# Out:
# Found data for 52 classification models under /home/apaulson/repos/AMPL_umbrella

# %% [markdown]
# ## Performance df format
# The multitask performance is provided **long-form**, meaning that each individual task is provided in a single row. Each model will have 1 row representing the full model metrics, and then 1 additional row for each task.

# %%
mtm.shape
# Out:
# (156, 59)

# %%
one_model=mtm[mtm.model_uuid==mtm.model_uuid.iloc[0]]
one_model
# Out:
#                              model_uuid    time_built  \
# 0  a94ece5a-2180-4704-884d-dfc2044b9118  1.712184e+09
# 1  a94ece5a-2180-4704-884d-dfc2044b9118  1.712184e+09
# 2  a94ece5a-2180-4704-884d-dfc2044b9118  1.712184e+09
#
#                                           model_path ampl_version  \
# 0  /home/apaulson/repos/AMPL_umbrella/ampl_berkel...        1.6.1
# 1  /home/apaulson/repos/AMPL_umbrella/ampl_berkel...        1.6.1
# 2  /home/apaulson/repos/AMPL_umbrella/ampl_berkel...        1.6.1
#
#   model_choice_score_type model_type prediction_type    split_strategy  \
# 0                 roc_auc         NN  classification  train_valid_test
# 1                 roc_auc         NN  classification  train_valid_test
# 2                 roc_auc         NN  classification  train_valid_test
#
#   split_test_frac                            split_uuid  ...  \
# 0            0.15  aa9b01ee-54a8-4bf3-b31f-6c025565f076  ...
# 1            0.15  aa9b01ee-54a8-4bf3-b31f-6c025565f076  ...
# 2            0.15  aa9b01ee-54a8-4bf3-b31f-6c025565f076  ...
#
#   best_test_matthews_cc best_test_npv best_test_num_compounds  \
# 0                   0.0      0.946875                   275.0
# 1                   0.0      0.950893                     NaN
# 2                   0.0      0.942857                     NaN
#
#   best_test_prc_auc_score best_test_precision best_test_recall_score  \
# 0                0.280639                 0.0                    0.0
# 1                0.243474                 0.0                    0.0
# 2                0.317803                 0.0                    0.0
#
#   best_test_roc_auc_score                               splitting_parameters  \
# 0                0.844377  {'base_splitter': 'scaffold', 'butina_cutoff':...
# 1                0.832693  {'base_splitter': 'scaffold', 'butina_cutoff':...
# 2                0.856061  {'base_splitter': 'scaffold', 'butina_cutoff':...
#
#                                model_parameters_dict feat_parameters_dict
# 0  {'batch_size': 50, 'best_epoch': 4, 'bias_init...                  NaN
# 1  {'batch_size': 50, 'best_epoch': 4, 'bias_init...                  NaN
# 2  {'batch_size': 50, 'best_epoch': 4, 'bias_init...                  NaN
#
# [3 rows x 59 columns]

# %% [markdown]
# ## Filtering for a single task
# You can filter your model metrics by `response_cols`. You can see that the `model_choice_score` is only valid for the full model, while individual metrics exist for each task in the model.

# %%
one_model[['model_uuid','response_cols','model_choice_score_type','best_valid_model_choice_score', 'best_valid_roc_auc_score']]
# Out:
#                              model_uuid response_cols model_choice_score_type  \
# 0  a94ece5a-2180-4704-884d-dfc2044b9118    full_model                 roc_auc
# 1  a94ece5a-2180-4704-884d-dfc2044b9118   active_bind                 roc_auc
# 2  a94ece5a-2180-4704-884d-dfc2044b9118  active_inhib                 roc_auc
#
#    best_valid_model_choice_score best_valid_roc_auc_score
# 0                       0.831739                 0.831739
# 1                            NaN                 0.691781
# 2                            NaN                 0.971698

# %%
binding_models=mtm[mtm.response_cols=='active_bind']

# %%
binding_models.sort_values('best_valid_roc_auc_score', ascending=False)[['model_uuid','model_type', 'response_cols',
                    'splitter','features','best_valid_roc_auc_score','model_parameters_dict','feat_parameters_dict','model_path']].head(5)
# Out:
#                                model_uuid model_type response_cols  \
# 121  fccea472-a05d-419c-a44d-fc33d9bfc932         NN   active_bind
# 127  d125c8bc-1727-4ed4-962f-bc612d7b8116         NN   active_bind
# 76   5d13b64d-f157-4a34-b834-d8f61de61fc4         NN   active_bind
# 85   837ae5e4-76d5-457c-ab43-cf5087ab24e5         NN   active_bind
# 130  7c9b9873-0f8f-47fc-8c39-7e5e7d269f6f         NN   active_bind
#
#               splitter features best_valid_roc_auc_score  \
# 121  multitaskscaffold     ecfp                 0.902968
# 127  multitaskscaffold     ecfp                  0.89726
# 76   multitaskscaffold     ecfp                 0.889269
# 85   multitaskscaffold     ecfp                 0.886986
# 130  multitaskscaffold     ecfp                 0.885845
#
#                                  model_parameters_dict  \
# 121  {'batch_size': 50, 'best_epoch': 4, 'bias_init...
# 127  {'batch_size': 50, 'best_epoch': 27, 'bias_ini...
# 76   {'batch_size': 50, 'best_epoch': 38, 'bias_ini...
# 85   {'batch_size': 50, 'best_epoch': 28, 'bias_ini...
# 130  {'batch_size': 50, 'best_epoch': 18, 'bias_ini...
#
#                       feat_parameters_dict  \
# 121  {'ecfp_radius': 2, 'ecfp_size': 1024}
# 127  {'ecfp_radius': 2, 'ecfp_size': 1024}
# 76   {'ecfp_radius': 2, 'ecfp_size': 1024}
# 85   {'ecfp_radius': 2, 'ecfp_size': 1024}
# 130  {'ecfp_radius': 2, 'ecfp_size': 1024}
#
#                                             model_path
# 121  /home/apaulson/repos/AMPL_umbrella/ampl_berkel...
# 127  /home/apaulson/repos/AMPL_umbrella/ampl_berkel...
# 76   /home/apaulson/repos/AMPL_umbrella/ampl_berkel...
# 85   /home/apaulson/repos/AMPL_umbrella/ampl_berkel...
# 130  /home/apaulson/repos/AMPL_umbrella/ampl_berkel...

# %% [markdown]
# ## Compatibility with other functions
# The filtered dataframe is largely compatible with other functions such as those from `hyper_perf_plots`

# %%
from atomsci.ddm.pipeline import hyper_perf_plots as hpp
import importlib
importlib.reload(hpp)
hpp.plot_hyper_perf(binding_models, scoretype='roc_auc_score', subset='valid', model_type='NN')

# %% [markdown]
# ## Single-task models
# This function can also be used to pull information for single-task models.

# %%
ST_dataset_key='/home/apaulson/repos/AMPL_umbrella/AMPL/atomsci/ddm/examples/tutorials2023/dataset/SLC6A3_classif_pKi_ge_8.csv'

stm=cmp.get_multitask_perf_from_files_new(result_dir, pred_type, dataset_key=ST_dataset_key)
# Out:
# Found data for 54 classification models under /home/apaulson/repos/AMPL_umbrella

# %% [markdown]
# For single-task models, only one row is returned per model.

# %%
onemod=stm[stm.model_uuid=='ef538063-7157-4981-9f5a-a4f1aebaf1ff']
onemod
# Out:
#                              model_uuid    time_built  \
# 0  ef538063-7157-4981-9f5a-a4f1aebaf1ff  1.712260e+09
#
#                                           model_path ampl_version  \
# 0  /home/apaulson/repos/AMPL_umbrella/AMPL/atomsc...        1.6.1
#
#   model_choice_score_type model_type prediction_type    split_strategy  \
# 0                 roc_auc         NN  classification  train_valid_test
#
#   split_test_frac                            split_uuid  ...  \
# 0            0.15  43e4337e-0845-4266-8ea0-e82c0cee4bd9  ...
#
#   best_test_matthews_cc best_test_npv best_test_num_compounds  \
# 0              0.080178           0.9                     273
#
#   best_test_prc_auc_score best_test_precision best_test_recall_score  \
# 0                0.439459            0.333333               0.035714
#
#   best_test_roc_auc_score                               splitting_parameters  \
# 0                0.854009  {'base_splitter': 'scaffold', 'butina_cutoff':...
#
#                                model_parameters_dict  \
# 0  {'batch_size': 50, 'best_epoch': 11, 'bias_ini...
#
#                     feat_parameters_dict
# 0  {'ecfp_radius': 2, 'ecfp_size': 1024}
#
# [1 rows x 60 columns]

# %%
stm.sort_values('best_valid_bal_accuracy', ascending=False)[['model_uuid', 'model_type', 'response_cols',
                    'splitter','features','weight_transform_type','model_parameters_dict','feat_parameters_dict','best_valid_bal_accuracy','model_path']].head(5)
# Out:
#                               model_uuid model_type response_cols  splitter  \
# 23  05e6ac5e-905b-4be0-9739-7432f2f626a6         NN        active  scaffold
# 13  7832b9e5-c7e7-4b79-9b8c-7daacd676f36         NN        active  scaffold
# 10  948f8730-5f52-44e2-8eaa-3dbb9ed00c01         NN        active  scaffold
# 17  68c7a414-cf1c-4a9a-94aa-fe7ceca88db8         NN        active  scaffold
# 3   340b303c-c152-482d-a876-5a0dd3318d66         NN        active  scaffold
#
#    features weight_transform_type  \
# 23     ecfp             balancing
# 13     ecfp                   NaN
# 10     ecfp                   NaN
# 17     ecfp                   NaN
# 3      ecfp                   NaN
#
#                                 model_parameters_dict  \
# 23  {'batch_size': 50, 'best_epoch': 7, 'bias_init...
# 13  {'batch_size': 50, 'best_epoch': 22, 'bias_ini...
# 10  {'batch_size': 50, 'best_epoch': 21, 'bias_ini...
# 17  {'batch_size': 50, 'best_epoch': 11, 'bias_ini...
# 3   {'batch_size': 50, 'best_epoch': 17, 'bias_ini...
#
#                      feat_parameters_dict  best_valid_bal_accuracy  \
# 23  {'ecfp_radius': 2, 'ecfp_size': 1024}                 0.771939
# 13  {'ecfp_radius': 2, 'ecfp_size': 1024}                 0.760204
# 10  {'ecfp_radius': 2, 'ecfp_size': 1024}                 0.754592
# 17  {'ecfp_radius': 2, 'ecfp_size': 1024}                 0.754082
# 3   {'ecfp_radius': 2, 'ecfp_size': 1024}                 0.752551
#
#                                            model_path
# 23  /home/apaulson/repos/AMPL_umbrella/AMPL/atomsc...
# 13  /home/apaulson/repos/AMPL_umbrella/AMPL/atomsc...
# 10  /home/apaulson/repos/AMPL_umbrella/AMPL/atomsc...
# 17  /home/apaulson/repos/AMPL_umbrella/AMPL/atomsc...
# 3   /home/apaulson/repos/AMPL_umbrella/AMPL/atomsc...

# %%
hpp.plot_train_valid_test_scores(stm, prediction_type=pred_type)

# %%
importlib.reload(hpp)
hpp.plot_hyper_perf(stm, scoretype='roc_auc_score', model_type='general')
